# %% [markdown]
# # Capstone — Resilient Navigation Under Spoofing
#
# Build a full workflow:
# 1. detect spoofing from the GNSS time series
# 2. maintain a resilient position estimate
# 3. report performance
#
# Suggested pipeline:
# - residual or innovation-based detection
# - gated GNSS updates
# - 1D Kalman filter using IMU prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../datasets/capstone_navigation_dataset.csv")
df.head()

# %% [markdown]
# ## Suggested deliverables
# - one detection plot
# - one navigation plot
# - one metric table with RMSE and detection delay

# %%
# TODO: implement your full solution here
